# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\selene.baez\Downloads\Registro-QCA.xlsx")

# %%
df
# Out:
#     numeroMuseo Muestras colectadas  numeroCampo    reino         filum  \
# 0     QCA238902                  NE         3873  Plantae  Tracheophyta
# 1     QCA237396                   x         4776  Plantae  Tracheophyta
# 2     QCA171172                   x         3687  Plantae  Tracheophyta
# 3       QCA5321                   x         3626  Plantae  Tracheophyta
# 4     QCA141562                   x         3707  Plantae  Tracheophyta
# ..          ...                 ...          ...      ...           ...
# 153   QCA141571                   x         3712  Plantae  Tracheophyta
# 154   QCA153272                   x         3928  Plantae  Tracheophyta
# 155   QCA190623                   x         3901  Plantae  Tracheophyta
# 156   QCA153391                   x         3690  Plantae  Tracheophyta
# 157   QCA212860                   x         4796  Plantae  Tracheophyta
#
#              clase         orden        familia         genero        especie  \
# ...

# %%
df = df[df["Muestras colectadas"]== "x"]
df["Nombre comun"] = df["numeroMuseo"]
df["Nombre técnico"] = df["reino"]+"-"+df["filum"]+"-"+df["clase"]+"-"+df["orden"]+"-"+df["familia"]+"-"+df["genero"]+"-"+df["especie"]
# Out:
# C:\Users\selene.baez\AppData\Local\Temp\ipykernel_10428\858477940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nombre comun"] = df["numeroMuseo"]
# C:\Users\selene.baez\AppData\Local\Temp\ipykernel_10428\858477940.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nombre técnico"] = df["reino"]+"-"+df["filum"]+"-"+df["clase"]+"-"+df["orden"]+"-"+df["familia"]+"-"+df["genero"]+"-"+df["especie"]

# %%
save = df[["Nombre técnico","Nombre comun"]]
save.to_excel("formulario_por_codigo.xlsx")
